# %% [markdown]
# # Ejercicio de Regresión Lineal
# # Pedro Antonio Mendoza Rivera 2008344 N1

# %% [markdown]
# En esta actividad se realizara un modelo de regresión lienal en el cual se hará la predicción de la calificación de un grupo de estudiantes tomando en cuenta el número de horas dedicadas a estudiar

# %% [markdown]
# El primer paso es crear las librerias a utilizar dentro de nuestro codigo

# %%
#Cargar las librerias
import numpy as np
import sklearn.linear_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# El segundo paso es crear o generar los datos con los cuales alimentaremos a nuestro modelo de regresión lineal

# %%
#Empezamos a generar los datos
np.random.seed(0)
horas_estudio = np.random.rand(100, 1) * 10
calificaciones = 2 * horas_estudio + np.random.randn(100,1) * 2

# %% [markdown]
# El tercer paso es empezar el preprocesamiento de los datos

# %%
# Dividir los datos en conjuntos de entrenamiento y prueba
train_data, test_data, train_labels, test_labels = train_test_split(horas_estudio, calificaciones, test_size=0.2, random_state=42)

# %%
data = pd.DataFrame({'Horas de Estudio': horas_estudio.flatten(),
                     'Calificaciones': calificaciones.flatten()})

print(data)
# Out:
#     Horas de Estudio  Calificaciones
# 0           5.488135        8.645970
# 1           7.151894       16.105440
# 2           6.027634       12.986592
# 3           5.448832        7.825176
# 4           4.236548       11.449600
# ..               ...             ...
# 95          1.831914        5.027016
# 96          5.865129       10.123439
# 97          0.201075       -0.976949
# 98          8.289400       15.667736
# 99          0.046955        0.128868
#
# [100 rows x 2 columns]

# %%
plt.scatter(horas_estudio, calificaciones)

plt.xlabel('Horas de Estudio')
plt.ylabel('Calificaciones')
plt.title('Relación entre Horas de Estudio y Calificaciones')

plt.show()

# %% [markdown]
# El cuarto paso es seleccionar y crear el modelo de regresión lineal

# %%
# Crear y entrenar el modelo de regresión lineal
model = sklearn.linear_model.LinearRegression()

# %%
model.fit(horas_estudio, calificaciones)
# Out:
# LinearRegression()

# %% [markdown]
# El quinto paso es hacer pruebas de nuestro modelo

# %%
#Realizar las predicciones del modelo entrenado
tiempo_estudio = [[13.5]]

calificacion_predicha = model.predict(tiempo_estudio)

print("La calificación predicha para {} horas de estudio es: {:.2f}".format(tiempo_estudio[0][0], calificacion_predicha[0][0]))
# Out:
# La calificación predicha para 13.5 horas de estudio es: 27.27

# %% [markdown]
# Generamos una grafica para ver como es que se comporta el modelo de regresión lineal que entrenamos

# %%
plt.scatter(test_data, test_labels, color='blue')

plt.plot(test_data, predicciones, color='red')
plt.title('Modelo de Regresión Lineal')
plt.xlabel('Horas de Estudio')
plt.ylabel('Calificación')

plt.show()
